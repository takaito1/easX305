# %% [markdown]
# # Week10: Redfield ratio in the P18 cruise
# (recycling code from Week 2)

# %%
import gsw
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 1. Download the bottle data in CSV format
# (https://cchdo.ucsd.edu/data/14186/33RO20161119_hy1.csv). Read in the bottle data into MATLAB or Python. Use the GSW package to calculate absolute salinity (hint: gsw_SA_from_SP) and conservative temperature (hint: gsw_CT_from_t).

# %%
# Step 1 download data from BATS and create data vectors
df=pd.read_csv('33RO20161119_hy1.csv',skiprows=149)
pd.set_option('display.max_columns', 500)
df
# Out:
#           EXPOCODE      SECT_ID  STNNBR  CASTNO  SAMPNO   BTLNBR  \
# 0              NaN          NaN     NaN     NaN     NaN      NaN
# 1     33RO20161119          P18     1.0     3.0     1.0  11010.0
# 2     33RO20161119          P18     1.0     3.0     2.0  11101.0
# 3     33RO20161119          P18     1.0     3.0     3.0  11102.0
# 4     33RO20161119          P18     1.0     3.0     4.0  11103.0
# ...            ...          ...     ...     ...     ...      ...
# 5096  33RO20161119          P18   212.0     1.0    21.0  11119.0
# 5097  33RO20161119          P18   212.0     1.0    22.0  11120.0
# 5098  33RO20161119          P18   212.0     1.0    23.0  11121.0
# 5099  33RO20161119          P18   212.0     1.0    24.0  11122.0
# 5100      END_DATA          NaN     NaN     NaN     NaN      NaN
#
#       BTLNBR_FLAG_W        DATE    TIME  LATITUDE  LONGITUDE        DEPTH  \
# 0               NaN         NaN     NaN       NaN        NaN       METERS
# 1               2.0  20161124.0  1417.0   22.6884  -110.0001         2619
# 2               2.0  20161124.0  1417.0   22.6884  -110.0001         2619
# 3               2.0  20161124.0  1417.0   22.6884  -110.0001         2619
# 4               2.0  20161124.0  1417.0   22.6884  -110.0001         2619
# ...             ...         ...     ...       ...        ...          ...
# 5096            2.0  20170129.0   245.0  -68.0668   -94.9996         4429
# 5097            2.0  20170129.0   245.0  -68.0668   -94.9996         4429
# 5098            2.0  20170129.0   245.0  -68.0668   -94.9996         4429
# 5099            2.0  20170129.0   245.0  -68.0668   -94.9996         4429
# 5100            NaN         NaN     NaN       NaN        NaN          NaN
#
#         CTDPRS     CTDTMP     CTDSAL  CTDSAL_FLAG_W     SALNTY  SALNTY_FLAG_W  \
# 0         DBAR     ITS-90     PSS-78            NaN     PSS-78            NaN
# 1       2641.6     1.8216    34.6618            2.0    34.6650            2.0
# 2       2350.6     1.8914    34.6537            2.0    34.6670            4.0
# 3       2100.1     2.0198    34.6435            2.0    34.6469            2.0
# 4       1924.7     2.2525    34.6298            2.0    34.6351            2.0
# ...        ...        ...        ...            ...        ...            ...
# 5096      90.7    -1.6019    33.8763            2.0    33.8789            2.0
# 5097      34.1    -0.3206    33.5649            2.0    33.5661            2.0
# 5098      17.9     1.7837    33.4734            2.0    33.4775            2.0
# 5099       3.3     1.6050    32.9924            2.0    32.9924            2.0
# 5100       NaN        NaN        NaN            NaN        NaN            NaN
#
#          CTDOXY  CTDOXY_FLAG_W    OXYGEN  OXYGEN_FLAG_W    SILCAT  \
# 0       UMOL/KG            NaN   UMOL/KG            NaN   UMOL/KG
# 1          99.1            4.0     104.9            2.0     159.2
# 2          93.9            2.0      96.5            2.0     158.1
# 3          85.7            2.0      88.9            2.0     154.3
# 4          72.4            2.0      76.6            2.0     151.2
# ...         ...            ...       ...            ...       ...
# 5096      338.4            2.0     336.7            2.0      41.7
# 5097      368.2            2.0     368.1            2.0      21.6
# 5098      338.9            2.0     336.7            2.0      19.1
# 5099      335.1            2.0     334.2            2.0      25.6
# 5100        NaN            NaN       NaN            NaN       NaN
#
#       SILCAT_FLAG_W    NITRAT  NITRAT_FLAG_W    NITRIT  NITRIT_FLAG_W  \
# 0               NaN   UMOL/KG            NaN   UMOL/KG            NaN
# 1               6.0      38.9            6.0      0.01            6.0
# 2               6.0      39.3            6.0      0.01            6.0
# 3               6.0      39.9            6.0      0.01            6.0
# 4               6.0      40.7            6.0      0.01            6.0
# ...             ...       ...            ...       ...            ...
# 5096            2.0      28.2            2.0      0.27            2.0
# 5097            2.0      23.6            2.0      0.23            2.0
# 5098            2.0      22.6            2.0      0.36            2.0
# 5099            2.0      22.9            2.0      0.43            2.0
# 5100            NaN       NaN            NaN       NaN            NaN
#
#         PHSPHT  PHSPHT_FLAG_W     CFC-11  CFC-11_FLAG_W     CFC-12  \
# 0      UMOL/KG            NaN    PMOL/KG            NaN    PMOL/KG
# 1        2.729            6.0     0.0094            2.0     0.0063
# 2        2.758            6.0     0.0090            2.0     0.0063
# 3        2.802            6.0  -999.0000            9.0  -999.0000
# 4        2.884            6.0     0.0099            6.0     0.0041
# ...        ...            ...        ...            ...        ...
# 5096     2.029            2.0  -999.0000            9.0  -999.0000
# 5097     1.674            2.0  -999.0000            9.0  -999.0000
# 5098     1.521            2.0  -999.0000            9.0  -999.0000
# 5099     1.503            2.0  -999.0000            9.0  -999.0000
# 5100       NaN            NaN        NaN            NaN        NaN
#
#       CFC-12_FLAG_W    TCARBN  TCARBN_FLAG_W    ALKALI  ALKALI_FLAG_W  PH_SWS  \
# 0               NaN   UMOL/KG            NaN   UMOL/KG            NaN     NaN
# 1               2.0    2366.1            6.0    2428.2            2.0  7.5127
# 2               2.0    2367.5            2.0    2427.2            2.0  7.4893
# 3               9.0    2368.3            2.0    2421.6            6.0  7.4699
# 4               6.0    2371.6            2.0    2419.5            2.0  7.4472
# ...             ...       ...            ...       ...            ...     ...
# 5096            9.0    2177.1            2.0    2286.5            2.0  7.6345
# 5097            9.0    2132.9            2.0    2271.2            6.0  7.7148
# 5098            9.0    2126.5            2.0    2265.8            2.0  7.7181
# 5099            9.0    2102.5            6.0    2228.4            2.0  7.7020
# 5100            NaN       NaN            NaN       NaN            NaN     NaN
#
#       PH_SWS_FLAG_W     PH_TMP       POC  POC_FLAG_W       PON  PON_FLAG_W  \
# 0               NaN      DEG C     UG/KG         NaN     UG/KG         NaN
# 1               2.0      25.00   -999.00         9.0   -999.00         9.0
# 2               2.0      25.00   -999.00         9.0   -999.00         9.0
# 3               2.0      25.00   -999.00         9.0   -999.00         9.0
# 4               2.0      25.00   -999.00         9.0   -999.00         9.0
# ...             ...        ...       ...         ...       ...         ...
# 5096            2.0      25.00   -999.00         9.0   -999.00         9.0
# 5097            2.0      25.00   -999.00         9.0   -999.00         9.0
# 5098            6.0      25.00   -999.00         9.0   -999.00         9.0
# 5099            2.0      25.00   -999.00         9.0   -999.00         9.0
# 5100            NaN        NaN       NaN         NaN       NaN         NaN
#
#               SF6  SF6_FLAG_W
# 0         PMOL/KG         NaN
# 1          0.0000         2.0
# 2          0.0031         2.0
# 3          -999.0         9.0
# 4          0.0112         6.0
# ...           ...         ...
# 5096       -999.0         9.0
# 5097       -999.0         9.0
# 5098       -999.0         9.0
# 5099       -999.0         9.0
# 5100          NaN         NaN
#
# [5101 rows x 47 columns]

# %%
# get data so we can calculate sigma-theta
pres=df['CTDPRS'][1:-1].astype(float)
sal=df['CTDSAL'][1:-1].astype(float)
temp=df['CTDTMP'][1:-1].astype(float)
lon=df['LONGITUDE'][1:-1].astype(float)
lat=df['LATITUDE'][1:-1].astype(float)
sflg=df['CTDSAL_FLAG_W'][1:-1].astype(int)

# %%
# first calculate absolute salinity
sa=gsw.SA_from_SP(sal,pres,lon,lat)
# then calculate conservative temperature
ct=gsw.CT_from_t(sa,temp,pres)
# then sigma theta
st=gsw.sigma0(sa,ct)

# %%
# now load N and P
no3=df['NITRAT'][1:-1].astype(float)
po4=df['PHSPHT'][1:-1].astype(float)
o2=df['OXYGEN'][1:-1].astype(float)
nflg=df['NITRAT_FLAG_W'][1:-1].astype(int)
pflg=df['PHSPHT_FLAG_W'][1:-1].astype(int)

# %%
# define conditions to include data
isgood=(nflg==2)&(pflg==2)
oxic=(o2>=20)
# combine conditions
ind=(isgood==True)&(oxic==True)

# %%
# trim down the data that matches desired conditions
x=po4[ind]
xlab='P'
y=no3[ind]
ylab='N'

# %%
# perform linear regression
c=np.cov(x,y)
a=c[0,1]/c[0,0] # slope
b=np.mean(y)-a*np.mean(x) # intercept
# calculate R2 value
r2=c[0,1]**2/c[0,0]/c[1,1]

# %%
# expand the regression line
x0=np.linspace(0,3,30)
y0=a*x0+b

# plot the result
plt.plot(x,y,'.')
plt.plot(x0,y0,'r-')
plt.xlabel(xlab+', umol/kg')
plt.ylabel(ylab+', umol/kg')
print(ylab+':'+xlab+' ratio is '+str(a.round(2))+' and R2 value is '+str(r2.round(2)))
# Out:
# N:P ratio is 15.61 and R2 value is 0.99
