# %% [markdown]
# # Binning the selected profiles
#
# QC criteria is entered to select certain profiles, then it generates binned data at standard depth levels
#
# (1) binning adjusted O2 profiles (monthly)
#
# (2) calculate statistical mean, standard deviation, sample count

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import os
import re
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# prepare grid cells
xW=np.arange(-180,180,1)
yS=np.arange(-90,90,1)
xC=np.arange(-180,180,1)+0.5
yC=np.arange(-90,90,1)+0.5
xE=np.arange(-180,180,1)+1.0
yN=np.arange(-90,90,1)+1.0
# time axis
Y=np.arange(2010,2021,1)
M=np.arange(1,13,1)
# empty array
mn=np.empty((360,180,26,12,np.size(Y))) # stat mean
sd=np.empty((360,180,26,12,np.size(Y))) # stdev
dd=np.empty((360,180,26,12,np.size(Y))) # count

# %%
# read in the summary statistics
df=pd.read_csv('float_summary_statsitics.csv')
rmse=df['RMSE_ADJ(500-2000m)'][:]
rmse0=df['RMSE_ADJ(0-2000m)'][:]

# %%
# find very good ones
ind=np.where(rmse<=10)
#
bins=np.linspace(0,30,20)
hdat=plt.hist(rmse,bins)
plt.title('histogram of RMSE for 500-2000m')
plt.xlabel('RMSE, micro mol/kg')
plt.ylabel('frequency')
plt.show()
fn=df['File'].to_numpy()
print('based on 500-2000m RMSE data')
print('there are ',np.size(rmse),' DOXY profiles')
print('there are ',np.size(ind),' acceptable profiles (rmse < 10uM)')
plt.show()
# Out:
# based on 500-2000m RMSE data
# there are  1528  DOXY profiles
# there are  481  acceptable profiles (rmse < 10uM)

# %%
# find very good ones
ind=np.where((rmse0<=15)&(rmse<10))
#
bins=np.linspace(0,30,20)
hdat=plt.hist(rmse0,bins)
plt.title('histogram of RMSE for 0-2000m')
plt.xlabel('RMSE, micro mol/kg')
plt.ylabel('frequency')
plt.show()
fn=df['File'].to_numpy()
print('based on 0-2000m and 500-2000m RMSE data')
print('there are ',np.size(ind),' acceptable profiles (rmse < 15uM for 0-2000m, and 10 for 500-2000m)')
plt.show()
# Out:
# based on 0-2000m and 500-2000m RMSE data
# there are  273  acceptable profiles (rmse < 15uM for 0-2000m, and 10 for 500-2000m)

# %%
def gen_stats(n): 
    # open the data file
    fltid=re.findall('\d+',fn[n])
    print('reading in '+fn[n])
    ds=xr.open_dataset(fn[n])
    Ns=np.shape(ds.O2_FLT) # profile, depth
    date=ds['JULD']
    time=pd.to_datetime(date)
    for p in range(0,Ns[0]):
        if pd.notna(time[p]):
            O2_FLT=ds.O2_FLT[p,:]
            x0=ds.LONGITUDE[p].data
            y0=ds.LATITUDE[p].data
            yr=int(time[p].year)
            mo=int(time[p].month)
            ix=np.where((x0>=xW)&(x0<xE))
            iy=np.where((y0>=yS)&(y0<yN))
            iyr=np.where((yr==Y))[0]
            imo=np.where((mo==M))[0]
            if (iyr.size>0):
                #print('(i,j,imo,iyr)=',str([ix,iy,imo,iyr]))
                for k in range(0,26):
                    if (np.isnan(O2_FLT[k])==False):
                        mn[ix,iy,k,imo,iyr]=np.squeeze(mn[ix,iy,k,imo,iyr])+O2_FLT[k]
                        sd[ix,iy,k,imo,iyr]=np.squeeze(sd[ix,iy,k,imo,iyr])+O2_FLT[k]**2
                        dd[ix,iy,k,imo,iyr]=np.squeeze(dd[ix,iy,k,imo,iyr])+1
    return ds

# %%
# run through all of the good profiles
for n in range(0,np.size(ind)):
    gen_stats(ind[0][n])
# Out:
# reading in compare_woa/1900722_26lev.nc
# reading in compare_woa/1901152_26lev.nc
# reading in compare_woa/1901153_26lev.nc
# reading in compare_woa/1901154_26lev.nc
# reading in compare_woa/1901158_26lev.nc
# reading in compare_woa/1901159_26lev.nc
# reading in compare_woa/1901206_26lev.nc
# reading in compare_woa/1901214_26lev.nc
# reading in compare_woa/1901467_26lev.nc
# reading in compare_woa/1902303_26lev.nc
# reading in compare_woa/2901555_26lev.nc
# reading in compare_woa/2902210_26lev.nc
# reading in compare_woa/2902211_26lev.nc
# reading in compare_woa/2902757_26lev.nc
# reading in compare_woa/2902762_26lev.nc
# reading in compare_woa/2902823_26lev.nc
# reading in compare_woa/3900333_26lev.nc
# reading in compare_woa/3900334_26lev.nc
# reading in compare_woa/3900344_26lev.nc
# reading in compare_woa/3900345_26lev.nc
# reading in compare_woa/3900346_26lev.nc
# reading in compare_woa/3901466_26lev.nc
# reading in compare_woa/3901667_26lev.nc
# reading in compare_woa/3901668_26lev.nc
# reading in compare_woa/3901669_26lev.nc
# reading in compare_woa/3901999_26lev.nc
# reading in compare_woa/3902114_26lev.nc
# reading in compare_woa/3902120_26lev.nc
# reading in compare_woa/3902121_26lev.nc
# reading in compare_woa/3902124_26lev.nc
# reading in compare_woa/3902126_26lev.nc
# reading in compare_woa/3902128_26lev.nc
# reading in compare_woa/3902130_26lev.nc
# reading in compare_woa/3902132_26lev.nc
# reading in compare_woa/4900093_26lev.nc
# reading in compare_woa/4900484_26lev.nc
# reading in compare_woa/4900485_26lev.nc
# reading in compare_woa/4900487_26lev.nc
# reading in compare_woa/4900494_26lev.nc
# reading in compare_woa/4900874_26lev.nc
# reading in compare_woa/4900880_26lev.nc
# reading in compare_woa/4901142_26lev.nc
# reading in compare_woa/4901801_26lev.nc
# reading in compare_woa/4903365_26lev.nc
# reading in compare_woa/5900420_26lev.nc
# reading in compare_woa/5900422_26lev.nc
# reading in compare_woa/5900952_26lev.nc
# reading in compare_woa/5900958_26lev.nc
# reading in compare_woa/5900965_26lev.nc
# reading in compare_woa/5900966_26lev.nc
# reading in compare_woa/5901043_26lev.nc
# reading in compare_woa/5901044_26lev.nc
# reading in compare_woa/5901045_26lev.nc
# reading in compare_woa/5901046_26lev.nc
# reading in compare_woa/5901047_26lev.nc
# reading in compare_woa/5901048_26lev.nc
# reading in compare_woa/5901049_26lev.nc
# reading in compare_woa/5901050_26lev.nc
# reading in compare_woa/5901051_26lev.nc
# reading in compare_woa/5901052_26lev.nc
# reading in compare_woa/5901054_26lev.nc
# reading in compare_woa/5901069_26lev.nc
# reading in compare_woa/5901071_26lev.nc
# reading in compare_woa/5901072_26lev.nc
# reading in compare_woa/5901073_26lev.nc
# reading in compare_woa/5901315_26lev.nc
# reading in compare_woa/5901316_26lev.nc
# reading in compare_woa/5901317_26lev.nc
# reading in compare_woa/5901336_26lev.nc
# reading in compare_woa/5901468_26lev.nc
# reading in compare_woa/5901491_26lev.nc
# reading in compare_woa/5901645_26lev.nc
# reading in compare_woa/5901647_26lev.nc
# reading in compare_woa/5901696_26lev.nc
# reading in compare_woa/5901697_26lev.nc
# reading in compare_woa/5901730_26lev.nc
# reading in compare_woa/5901736_26lev.nc
# reading in compare_woa/5901739_26lev.nc
# reading in compare_woa/5901740_26lev.nc
# reading in compare_woa/5901741_26lev.nc
# reading in compare_woa/5901742_26lev.nc
# reading in compare_woa/5901744_26lev.nc
# reading in compare_woa/5902105_26lev.nc
# reading in compare_woa/5902261_26lev.nc
# reading in compare_woa/5902297_26lev.nc
# reading in compare_woa/5902299_26lev.nc
# reading in compare_woa/5902300_26lev.nc
# reading in compare_woa/5902301_26lev.nc
# reading in compare_woa/5902304_26lev.nc
# reading in compare_woa/5903257_26lev.nc
# reading in compare_woa/5903258_26lev.nc
# reading in compare_woa/5903382_26lev.nc
# reading in compare_woa/5903385_26lev.nc
# reading in compare_woa/5903592_26lev.nc
# reading in compare_woa/5903593_26lev.nc
# reading in compare_woa/5903629_26lev.nc
# reading in compare_woa/5903656_26lev.nc
# reading in compare_woa/5903713_26lev.nc
# reading in compare_woa/5903719_26lev.nc
# reading in compare_woa/5903723_26lev.nc
# reading in compare_woa/5903753_26lev.nc
# reading in compare_woa/5903887_26lev.nc
# reading in compare_woa/5903888_26lev.nc
# reading in compare_woa/5904094_26lev.nc
# reading in compare_woa/5904145_26lev.nc
# reading in compare_woa/5904147_26lev.nc
# reading in compare_woa/5904172_26lev.nc
# reading in compare_woa/5904227_26lev.nc
# reading in compare_woa/5904395_26lev.nc
# reading in compare_woa/5904465_26lev.nc
# reading in compare_woa/5904466_26lev.nc
# reading in compare_woa/5904477_26lev.nc
# reading in compare_woa/5904487_26lev.nc
# reading in compare_woa/5904655_26lev.nc
# reading in compare_woa/5904674_26lev.nc
# reading in compare_woa/5904685_26lev.nc
# reading in compare_woa/5904694_26lev.nc
# reading in compare_woa/5904761_26lev.nc
# reading in compare_woa/5904763_26lev.nc
# reading in compare_woa/5904842_26lev.nc
# reading in compare_woa/5904843_26lev.nc
# reading in compare_woa/5904844_26lev.nc
# reading in compare_woa/5904850_26lev.nc
# reading in compare_woa/5904851_26lev.nc
# reading in compare_woa/5904882_26lev.nc
# reading in compare_woa/5905077_26lev.nc
# reading in compare_woa/5905078_26lev.nc
# reading in compare_woa/5905104_26lev.nc
# reading in compare_woa/5905107_26lev.nc
# reading in compare_woa/5905109_26lev.nc
# reading in compare_woa/5905111_26lev.nc
# reading in compare_woa/5905113_26lev.nc
# reading in compare_woa/5905132_26lev.nc
# reading in compare_woa/5905133_26lev.nc
# reading in compare_woa/5905165_26lev.nc
# reading in compare_woa/5905167_26lev.nc
# reading in compare_woa/5905194_26lev.nc
# reading in compare_woa/5905198_26lev.nc
# reading in compare_woa/5905397_26lev.nc
# reading in compare_woa/5905441_26lev.nc
# reading in compare_woa/5905442_26lev.nc
# reading in compare_woa/5905637_26lev.nc
# reading in compare_woa/5905971_26lev.nc
# reading in compare_woa/5905972_26lev.nc
# reading in compare_woa/5905974_26lev.nc
# reading in compare_woa/5905977_26lev.nc
# reading in compare_woa/5905980_26lev.nc
# reading in compare_woa/5905985_26lev.nc
# reading in compare_woa/5905986_26lev.nc
# reading in compare_woa/5905988_26lev.nc
# reading in compare_woa/5906005_26lev.nc
# reading in compare_woa/5906006_26lev.nc
# reading in compare_woa/5906034_26lev.nc
# reading in compare_woa/5906039_26lev.nc
# reading in compare_woa/5906040_26lev.nc
# reading in compare_woa/5906201_26lev.nc
# reading in compare_woa/5906202_26lev.nc
# reading in compare_woa/5906203_26lev.nc
# reading in compare_woa/5906204_26lev.nc
# reading in compare_woa/5906208_26lev.nc
# reading in compare_woa/5906213_26lev.nc
# reading in compare_woa/5906222_26lev.nc
# reading in compare_woa/5906225_26lev.nc
# reading in compare_woa/5906235_26lev.nc
# reading in compare_woa/5906238_26lev.nc
# reading in compare_woa/5906301_26lev.nc
# reading in compare_woa/5906302_26lev.nc
# reading in compare_woa/5906303_26lev.nc
# reading in compare_woa/5906304_26lev.nc
# reading in compare_woa/5906307_26lev.nc
# reading in compare_woa/5906310_26lev.nc
# reading in compare_woa/5906311_26lev.nc
# reading in compare_woa/5906318_26lev.nc
# reading in compare_woa/5906319_26lev.nc
# reading in compare_woa/5906339_26lev.nc
# reading in compare_woa/5906440_26lev.nc
# reading in compare_woa/5906635_26lev.nc
# reading in compare_woa/5906645_26lev.nc
# reading in compare_woa/6900889_26lev.nc
# reading in compare_woa/6900944_26lev.nc
# reading in compare_woa/6901437_26lev.nc
# reading in compare_woa/6901439_26lev.nc
# reading in compare_woa/6901467_26lev.nc
# reading in compare_woa/6901468_26lev.nc
# reading in compare_woa/6901473_26lev.nc
# reading in compare_woa/6901474_26lev.nc
# reading in compare_woa/6901486_26lev.nc
# reading in compare_woa/6901490_26lev.nc
# reading in compare_woa/6901522_26lev.nc
# reading in compare_woa/6901523_26lev.nc
# reading in compare_woa/6901595_26lev.nc
# reading in compare_woa/6901602_26lev.nc
# reading in compare_woa/6901603_26lev.nc
# reading in compare_woa/6901627_26lev.nc
# reading in compare_woa/6901631_26lev.nc
# reading in compare_woa/6901646_26lev.nc
# reading in compare_woa/6901754_26lev.nc
# reading in compare_woa/6901755_26lev.nc
# reading in compare_woa/6901759_26lev.nc
# reading in compare_woa/6901764_26lev.nc
# reading in compare_woa/6901766_26lev.nc
# reading in compare_woa/6901768_26lev.nc
# reading in compare_woa/6901771_26lev.nc
# reading in compare_woa/6901773_26lev.nc
# reading in compare_woa/6901865_26lev.nc
# reading in compare_woa/6901886_26lev.nc
# reading in compare_woa/6902547_26lev.nc
# reading in compare_woa/6902549_26lev.nc
# reading in compare_woa/6902686_26lev.nc
# reading in compare_woa/6902701_26lev.nc
# reading in compare_woa/6902800_26lev.nc
# reading in compare_woa/6902802_26lev.nc
# reading in compare_woa/6902805_26lev.nc
# reading in compare_woa/6902807_26lev.nc
# reading in compare_woa/6902808_26lev.nc
# reading in compare_woa/6902810_26lev.nc
# reading in compare_woa/6902811_26lev.nc
# reading in compare_woa/6902819_26lev.nc
# reading in compare_woa/6902828_26lev.nc
# reading in compare_woa/6902878_26lev.nc
# reading in compare_woa/6902879_26lev.nc
# reading in compare_woa/6902906_26lev.nc
# reading in compare_woa/6902907_26lev.nc
# reading in compare_woa/6902908_26lev.nc
# reading in compare_woa/6902982_26lev.nc
# reading in compare_woa/6902984_26lev.nc
# reading in compare_woa/6903024_26lev.nc
# reading in compare_woa/6903025_26lev.nc
# reading in compare_woa/6903028_26lev.nc
# reading in compare_woa/6903032_26lev.nc
# reading in compare_woa/6903034_26lev.nc
# reading in compare_woa/6903039_26lev.nc
# reading in compare_woa/6903041_26lev.nc
# reading in compare_woa/6903066_26lev.nc
# reading in compare_woa/6903071_26lev.nc
# reading in compare_woa/6903080_26lev.nc
# reading in compare_woa/6903081_26lev.nc
# reading in compare_woa/6903083_26lev.nc
# reading in compare_woa/6903086_26lev.nc
# reading in compare_woa/6903124_26lev.nc
# reading in compare_woa/6903190_26lev.nc
# reading in compare_woa/6903204_26lev.nc
# reading in compare_woa/6903225_26lev.nc
# reading in compare_woa/6903273_26lev.nc
# reading in compare_woa/6903550_26lev.nc
# reading in compare_woa/6903551_26lev.nc
# reading in compare_woa/6903553_26lev.nc
# reading in compare_woa/6903554_26lev.nc
# reading in compare_woa/6903556_26lev.nc
# reading in compare_woa/6903557_26lev.nc
# reading in compare_woa/6903558_26lev.nc
# reading in compare_woa/6903567_26lev.nc
# reading in compare_woa/6903568_26lev.nc
# reading in compare_woa/6903569_26lev.nc
# reading in compare_woa/6903572_26lev.nc
# reading in compare_woa/6903573_26lev.nc
# reading in compare_woa/6903574_26lev.nc
# reading in compare_woa/6903575_26lev.nc
# reading in compare_woa/6903577_26lev.nc
# reading in compare_woa/6903582_26lev.nc
# reading in compare_woa/6903799_26lev.nc
# reading in compare_woa/6903802_26lev.nc
# reading in compare_woa/6903871_26lev.nc
# reading in compare_woa/6903873_26lev.nc
# reading in compare_woa/6903874_26lev.nc
# reading in compare_woa/6903875_26lev.nc
# reading in compare_woa/6903876_26lev.nc
# reading in compare_woa/6903877_26lev.nc
# reading in compare_woa/6904113_26lev.nc
# reading in compare_woa/6904114_26lev.nc
# reading in compare_woa/6904115_26lev.nc
# reading in compare_woa/7900566_26lev.nc
# reading in compare_woa/7900589_26lev.nc

# %%
# calculate mean
mn=mn/dd
# Out:
# /var/folders/s6/962q46653xd_fxwlc18l0t8w00bhjp/T/ipykernel_54961/472480551.py:2: RuntimeWarning: invalid value encountered in true_divide
#   mn=mn/dd

# %%
# calculate standard deviation
sd=np.sqrt(sd/dd - mn**2)
# Out:
# /var/folders/s6/962q46653xd_fxwlc18l0t8w00bhjp/T/ipykernel_54961/3944058456.py:2: RuntimeWarning: invalid value encountered in true_divide
#   sd=np.sqrt(sd/dd - mn**2)

# %%
# save the result
zstd=np.array([0,10,20,30,50,75,100,125,150,200,250,300,400,
               500,600,700,800,900,1000,1100,1200,1300,1400,
               1500,1750,2000])
time = pd.date_range("2010-01-01", freq="M", periods=np.size(Y)*12)
o_mn=xr.DataArray( np.empty((360,180,26,(12*np.size(Y)))) ,  
                       [("longitude",xC),("latitude",yC), 
                        ("depth",zstd),("time",time) 
                       ],name='o_mn',
                  attrs=dict(longname="statistical mean of o2",
                             units="micro-mol/kg"), )
o_sd=xr.DataArray( np.empty((360,180,26,(12*np.size(Y)))) ,  
                       [("longitude",xC),("latitude",yC), 
                        ("depth",zstd),("time",time) 
                       ],name='o_sd',
                  attrs=dict(longname="standard deviation of o2",
                             units="micro-mol/kg"), )
o_dd=xr.DataArray( np.empty((360,180,26,(12*np.size(Y)))) ,  
                       [("longitude",xC),("latitude",yC), 
                        ("depth",zstd),("time",time) 
                       ],name='o_dd',
                  attrs=dict(longname="data count of o2",
                             units="non-dimensional"), )
for i in range(0,np.size(Y)):
    for j in range(0,np.size(M)):
        tind=12*(i-1)+j
        o_mn[:,:,:,tind]=mn[:,:,:,j,i]        
        o_sd[:,:,:,tind]=sd[:,:,:,j,i]        
        o_dd[:,:,:,tind]=dd[:,:,:,j,i]        

ds_out=xr.merge([o_mn,o_sd,o_dd])
wn='o2_ARGO_woa09bin_26lev.nc'
ds_out.to_netcdf(wn,mode='w')
